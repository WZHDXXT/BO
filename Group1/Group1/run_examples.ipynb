# %% [markdown]
# # Increasing the Scope as You Learn: BAxUS

# %% [markdown]
# ## 1. Algorithm

# %% [markdown]
# <img src="algorithm1.png">

# %% [markdown]
# <h2>2. Command line options
# <table class="colwidths-given longtable docutils align-default" style="font-size:16px; ">
# <colgroup>
# <col style="width: 15%" />
# <col style="width: 10%" />
# <col style="width: 25%" />
# <col style="width: 10%" />
# <col style="width: 40%" />
# </colgroup>
# <thead>
# <tr class="row-odd"><th class="head"><p><strong>Name</strong></p></th>
# <th class="head"><p><strong>Shortcut</strong></p></th>
# <th class="head"><p><strong>Full argument</strong></p></th>
# <th class="head"><p><strong>Default</strong></p></th>
# <th class="head"><p><strong>Description</strong></p></th>
# </tr>
# </thead>
# <tbody>
# <tr class="row-even"><td><p>Algorithm</p></td>
# <td><p>-a</p></td>
# <td><p>–algorithms</p></td>
# <td><p>baxus</p></td>
# <td><p>The algorithm to run. Has to be from baxus, embedded_turbo_target_dim, embedded_turbo_effective_dim, embedded_turbo_2_effective_dim, random_search</p></td>
# </tr>
# <tr class="row-odd"><td><p>Function</p></td>
# <td><p>-f</p></td>
# <td><p>–functions</p></td>
# <td><p>None</p></td>
# <td><p>One ore several test functions. Has to be from hartmann6, branin2, rosenbrock5, rosenbrock10, ackley, rosenbrock, levy, dixonprice, griewank, michalewicz, rastrigin, svm, lasso-high, lasso-dna, lasso-high, lasso-medium, lasso-leukemia, lasso-rcv1, lasso-breastcancer, lasso-diabetes, lasso-simple, lasso-hard, mopta08, hartmann6in1000_rotated, shiftedackley10.</p></td>
# </tr>
# <tr class="row-even"><td><p>Input dimensionality</p></td>
# <td><p>-id</p></td>
# <td><p>–input-dim</p></td>
# <td><p>100</p></td>
# <td><p>Input dimensionality of the function. This is overriden when the function has a fixed dimensionality.</p></td>
# </tr>
# <tr class="row-odd"><td><p>Target dimensionality</p></td>
# <td><p>-td</p></td>
# <td><p>–target-dim</p></td>
# <td><p>10</p></td>
# <td><p>(Initial) target dimensionality of the function. Whether initial or not depends on the algorithm. Initial for <code class="docutils literal notranslate"><span class="pre">AdaTheSBO-1</span></code> and <code class="docutils literal notranslate"><span class="pre">AdaTheSBO-m</span></code> as they adapt the target dimensionality.</p></td>
# </tr>
# <tr class="row-even"><td><p>Acquisition function</p></td>
# <td><p>None</p></td>
# <td><p>–acquisition-function</p></td>
# <td><p>ts</p></td>
# <td><p>Either <code class="docutils literal notranslate"><span class="pre">ts</span></code> (Thompson sampling) or <code class="docutils literal notranslate"><span class="pre">ei</span></code> (Expected improvement)</p></td>
# </tr>
# <tr class="row-odd"><td><p>Embedding type</p></td>
# <td><p>None</p></td>
# <td><p>–embedding-type</p></td>
# <td><p>baxus</p></td>
# <td><p>Either <code class="docutils literal notranslate"><span class="pre">baxus</span></code> (for the BAxUS embedding) or <code class="docutils literal notranslate"><span class="pre">hesbo</span></code> (for the HeSBO embedding)</p></td>
# </tr>
# <tr class="row-even"><td><p>Adjust initial target dimensionality</p></td>
# <td><p>None</p></td>
# <td><p>–adjust-initial-target-dimension</p></td>
# <td><p>not set</p></td>
# <td><p>Whether to adjust the initial target dimensionality as described in the BAxUS paper.</p></td>
# </tr>
# <tr class="row-odd"><td><p>Number of initial samples</p></td>
# <td><p>-n</p></td>
# <td><p>–n-init</p></td>
# <td><p>None (set to target dimensionality + 1 if not set)</p></td>
# <td><p>Number of DOE samples.</p></td>
# </tr>
# <tr class="row-even"><td><p>Number of repetitions</p></td>
# <td><p>-r</p></td>
# <td><p>–num-repetitions</p></td>
# <td><p>1</p></td>
# <td><p>Number of repetitions of the run.</p></td>
# </tr>
# <tr class="row-odd"><td><p>Number of evaluations</p></td>
# <td><p>-m</p></td>
# <td><p>–max-evals</p></td>
# <td><p>300</p></td>
# <td><p>Number of evaluations. Cma-ES might use a few more.</p></td>
# </tr>
# <tr class="row-even"><td><p>Initial baselength</p></td>
# <td><p>-l</p></td>
# <td><p>–initial-baselength</p></td>
# <td><p>0.8</p></td>
# <td><p>The initial base length of the trust region (default value is as in the TuRBO paper).</p></td>
# </tr>
# <tr class="row-odd"><td><p>Minimum baselength</p></td>
# <td><p>-lmin</p></td>
# <td><p>–min-baselength</p></td>
# <td><p>0.5^7</p></td>
# <td><p>The minimum base length a trust region is allowed to obtain (default value is as in the TuRBO paper).</p></td>
# </tr>
# <tr class="row-even"><td><p>Maximum baselength</p></td>
# <td><p>-l_max</p></td>
# <td><p>–max-baselength</p></td>
# <td><p>1.6</p></td>
# <td><p>The maximum base length a trust region is allowed to obtain (default value is as in the TuRBO paper).</p></td>
# </tr>
# <tr class="row-odd"><td><p>Noise standard deviation</p></td>
# <td><p>None</p></td>
# <td><p>–noise-std</p></td>
# <td><p>0</p></td>
# <td><p>The standard deviation of the noise. Whether this is used or not depends on the benchmark. It is generally only recognized for synthetic benchmarks like <code class="docutils literal notranslate"><span class="pre">Branin2</span></code> but also for the synthetic <code class="docutils literal notranslate"><span class="pre">Lasso</span></code> versions.</p></td>
# </tr>
# <tr class="row-even"><td><p>Results directory</p></td>
# <td><p>None</p></td>
# <td><p>–results-dir</p></td>
# <td><p>results</p></td>
# <td><p>The directory to which the results are written. Relative to the path from which the run was started.</p></td>
# </tr>
# <tr class="row-odd"><td><p>Run description</p></td>
# <td><p>None</p></td>
# <td><p>–run-description</p></td>
# <td><p>None</p></td>
# <td><p>Short description that will be added to the run directory</p></td>
# </tr>
# <tr class="row-even"><td><p>MLE multistart samples</p></td>
# <td><p>None</p></td>
# <td><p>–multistart-samples</p></td>
# <td><p>100</p></td>
# <td><p>Number of multistart samples for the MLE GD optimization. Samples will be drawn from latin hypercube</p></td>
# </tr>
# <tr class="row-odd"><td><p>Multistarts after sampling</p></td>
# <td><p>None</p></td>
# <td><p>–multistart-after-sample</p></td>
# <td><p>10</p></td>
# <td><p>Only recognized for ‘–mle-optimization sample-and-choose-best’. Number of multi-start gradient descent optimization out of the <code class="docutils literal notranslate"><span class="pre">--multistart-samples</span></code> best ones.</p></td>
# </tr>
# <tr class="row-even"><td><p>MLE optimization method</p></td>
# <td><p>None</p></td>
# <td><p>–mle-optimization</p></td>
# <td><p>sample-and-choose-best</p></td>
# <td><p>Either <code class="docutils literal notranslate"><span class="pre">multistart-gd</span></code> or <code class="docutils literal notranslate"><span class="pre">sample-and-choose-best</span></code>.</p></td>
# </tr>
# <tr class="row-odd"><td><p>Number of MLE gradient updates</p></td>
# <td><p>None</p></td>
# <td><p>–mle-training-steps</p></td>
# <td><p>50</p></td>
# <td><p>Number of GD steps in MLE maximization.</p></td>
# </tr>
# <tr class="row-even"><td><p>Budget until input dimensionality</p></td>
# <td><p>None</p></td>
# <td><p>–budget-until-input-dim</p></td>
# <td><p>0</p></td>
# <td><p>The budget after which BAxUS will roughly reach the input dimensionality (see paper for details). If <code class="docutils literal notranslate"><span class="pre">0</span></code>: this setting is ignored</p></td>
# </tr>
# <tr class="row-odd"><td><p>Verbose mode</p></td>
# <td><p>-v</p></td>
# <td><p>–verbose</p></td>
# <td><p>not set</p></td>
# <td><p>Whether to print verbose messages</p></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ### import packages

# %%
import math
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sys
from baxus import benchmark_runner
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# ## 3. Run with specific setting to see the process

# %% [markdown]
# input dimentionality = 100
# target dimentionality = 1
# number of initial samples = 10
# number of repetition = 1
# number of evaluations = 1000
# objective function: branin2
# algorithm: baxus
# Whether to adjust the initial target dimensionality: True

# %% [markdown]
# <img src="initial_d.jpg" >

# %%
s = ['-id', '100', '-td', '1', '-n', '10', '-r', '1', '-m', '1000', '-f', 'branin2', '-a', 'baxus', '--adjust-initial-target-dimension']
benchmark_runner.main(s)
# Out:
# 10/19/2024 05:16:12 AM INFO: benchmark_function.py: effective dims: [0, 1]
# 10/19/2024 05:16:12 AM INFO: benchmark_runner.py: running combination branin2_in_dim_100_t_dim1_n_init_10
# 10/19/2024 05:16:12 AM INFO: benchmark_runner.py: *** BAxUS***
# 10/19/2024 05:16:12 AM INFO: baxus.py: ****************************************************************************************
# * Can reach a difference of 28 with init target dim  of 2 after 3 splits. Adjusting... *
# ****************************************************************************************
# 10/19/2024 05:16:12 AM INFO: embeddedturbo.py: eval 0: creating HeSBO embedding for TuRBO instance...
# 10/19/2024 05:16:12 AM INFO: embeddedturbo.py: important target dims: [0]
# 10/19/2024 05:16:12 AM INFO: embeddedturbo.py: Running with the following behavior
#
# 	-initial base length: 0.8
# 	-maximum base length: 1.6
# 	-minimum base length: 0.0078125
# 	-success tolerance: 3
# 	-acquisition_functions: THOMPSON_SAMPLING
# ...

# %%
data = np.array(pd.read_csv('first.csv', header=None))
data = data[1:][:, 1:]
plt.ylim((0, 5))
plt.plot(range(data.shape[0]), data[:, -1].astype(np.float32))
plt.show()

# %% [markdown]
# ## 4. Reproducing the results from the paper
# ### 1) success probability

# %% [markdown]
# ### Define the HeSBO success probability:

# %% [markdown]
# <img src="HESBO.JPG" width=300>

# %%
def succ_hesbo(D,d,de):
    """
    HeSBO success probability (independent of D)
    """
    if d<de:
        return 0
    return np.math.factorial(d)/(np.math.factorial(d-de)*d**de)

# %% [markdown]
# ### Define the BAxUS success probability:

# %% [markdown]
# <img src="BAXUS.JPG">

# %%
def succ_baxus(D,d,de):
    """
    BAxUS success probability
    """
    if d<de:
        return 0
    beta_s = D//d
    beta_l = math.ceil(D/d)
    dl = D-d*beta_s
    ds = d-dl

    numerator = sum(math.comb(ds,i)*math.comb(dl,de-i)*beta_s**i*beta_l**(de-i) for i in range(de+1))
    return numerator/math.comb(D,de)

# %%
fig, axs = plt.subplots(1,3, figsize=(7.5,3.2), sharey=True)

plt.rc('text', usetex=True)
plt.rcParams["font.family"] = "serif"
plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
plt.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
plt.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'

for p, D in enumerate([100,500,1000]):
    for o, d in enumerate([20]):
        ax = axs[p]
        hesbos = [succ_hesbo(D,i,d) for i in range(d,D+1)]
        baxuss = [succ_baxus(D,i,d) for i in range(d,D+1)]
        ax.grid(which='major', color='#CCCCCC', linestyle='--')
        ax.grid(which='minor', color='#CCCCCC', linestyle=':')
        ax.plot(np.arange(d,len(hesbos)+d), baxuss, color="#E66100", marker="*", markevery=(D-d)//4, label=r"BAxUS")
        ax.plot(np.arange(d,len(hesbos)+d), hesbos, color="#5D3A9B", marker="^", markevery=(D-d)//4, label=r"HeSBO")

        ax.set_title(f"$D$={D}, $d_e$={d}")
        if o == 0:
            ax.set_xlabel(r"$d$", fontsize=12)
        if p == 0:
            ax.set_ylabel(r"$p(Y^*; D,d,d_e)$", fontsize=12)
handles, labels = axs[0].get_legend_handles_labels()
fig.tight_layout()
plt.subplots_adjust(bottom=0.35)
fig.legend(handles, labels, loc='lower center', ncol=2, fancybox=True, borderaxespad=2, columnspacing=3,fontsize="large")
plt.show()
# Out:
# /tmp/ipykernel_26198/2860084817.py:7: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   return np.math.factorial(d)/(np.math.factorial(d-de)*d**de)

# %% [markdown]
# ### compare random search and baxus on hartmann6

# %%
s = ['-a', 'random_search', '-f', 'hartmann6', '-m', '100', '-r', '1', '-id', '500', '-td', '1', '--adjust-initial-target-dimension', '--n-init', '10']
benchmark_runner.main(s)
# Out:
# 10/19/2024 11:27:46 PM INFO: benchmark_function.py: effective dims: [0, 1, 2, 3, 4, 5]
# 10/19/2024 11:27:46 PM INFO: benchmark_runner.py: running combination hartmann6_in_dim_500_t_dim1_n_init_10
# 10/19/2024 11:27:46 PM INFO: benchmark_runner.py: *****************
# * Random Search *
# *****************
# 10/19/2024 11:27:46 PM INFO: benchmark_utils.py: starting repetition 0
# 10/19/2024 11:27:46 PM WARNING: other_methods.py: No reset implemented.

# %%
s = ['-a', 'baxus', '-f', 'hartmann6', '-m', '100', '-r', '1', '-id', '500', '-td', '1', '--adjust-initial-target-dimension', '--n-init', '10']
benchmark_runner.main(s)
# Out:
# 10/19/2024 09:55:46 PM INFO: benchmark_function.py: effective dims: [0, 1, 2, 3, 4, 5]
# 10/19/2024 09:55:46 PM INFO: benchmark_runner.py: running combination hartmann6_in_dim_200_t_dim1_n_init_10
# 10/19/2024 09:55:46 PM INFO: benchmark_runner.py: *** BAxUS***
# 10/19/2024 09:55:46 PM INFO: baxus.py: ***************************************************************************************
# * Can reach a difference of 8 with init target dim  of 3 after 3 splits. Adjusting... *
# ***************************************************************************************
# 10/19/2024 09:55:46 PM INFO: embeddedturbo.py: eval 0: creating HeSBO embedding for TuRBO instance...
# 10/19/2024 09:55:46 PM INFO: embeddedturbo.py: important target dims: [0, 1, 2]
# 10/19/2024 09:55:46 PM INFO: embeddedturbo.py: Running with the following behavior
#
# 	-initial base length: 0.8
# 	-maximum base length: 1.6
# 	-minimum base length: 0.0078125
# 	-success tolerance: 3
# ...

# %%
data = np.array(pd.read_csv('hartmann6.csv', header=None))
data_random = np.array(pd.read_csv('random_ha6.csv', header=None))
data = data[1:][:, 1:]
data_random = data_random[1:][:, 1:]
plt.ylim((-1, 10))
plt.ylabel('regret')
plt.plot(range(data.shape[0]), data[:, -1].astype(np.float32), c ='r')
plt.plot(range(data_random.shape[0]), data_random[:, -1].astype(np.float32), c ='b')
plt.show()

# %% [markdown]
# ### Baxus on Lasso-Hard and Lasso-High

# %%
s = ['-a', 'baxus', '-f', 'lasso-hard', '-m', '100', '-r', '1', '-id', '200', '-td', '1', '--adjust-initial-target-dimension', '--noise-std', '1.0', '--n-init', '10']
benchmark_runner.main(s)
# Out:
# 10/20/2024 03:15:53 AM WARNING: real_world_benchmarks.py: LassoBenchmark with noise_std 1.0 chosen. Will use noisy version with snr ratio 10. The exact value of noise_std will be ignored.
# 10/20/2024 03:15:53 AM INFO: real_world_benchmarks.py: function effective dimensions: [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980]
# 10/20/2024 03:15:53 AM INFO: benchmark_runner.py: running combination lasso-hard_in_dim_1000_t_dim1_n_init_10_noise_1.0
# 10/20/2024 03:15:53 AM INFO: benchmark_runner.py: *** BAxUS***
# 10/20/2024 03:15:53 AM INFO: baxus.py: ****************************************************************************************
# * Can reach a difference of 24 with init target dim  of 1 after 5 splits. Adjusting... *
# ...

# %%
data = np.array(pd.read_csv('lasso-hard.csv', header=None))
data = data[1:][:, 1:]
plt.ylim((-1, 20))
plt.ylabel('Function Value')
plt.plot(range(data.shape[0]), data[:, -1].astype(np.float32), c ='r')
plt.show()

# %%
s = ['-a', 'baxus', '-f', 'lasso-high', '-m', '100', '-r', '1', '-id', '200', '-td', '1', '--adjust-initial-target-dimension', '--noise-std', '1.0', '--n-init', '10']
benchmark_runner.main(s)
# Out:
# 10/20/2024 02:30:43 AM WARNING: real_world_benchmarks.py: LassoBenchmark with noise_std 1.0 chosen. Will use noisy version with snr ratio 10. The exact value of noise_std will be ignored.
# 10/20/2024 02:30:46 AM INFO: real_world_benchmarks.py: function effective dimensions: [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280]
# 10/20/2024 02:30:46 AM INFO: benchmark_runner.py: running combination lasso-high_in_dim_300_t_dim1_n_init_10_noise_1.0
# 10/20/2024 02:30:46 AM INFO: benchmark_runner.py: *** BAxUS***
# 10/20/2024 02:30:46 AM INFO: baxus.py: ****************************************************************************************
# * Can reach a difference of 44 with init target dim  of 1 after 4 splits. Adjusting... *
# ****************************************************************************************
# 10/20/2024 02:30:46 AM INFO: embeddedturbo.py: eval 0: creating HeSBO embedding for TuRBO instance...
# ...

# %%
data = np.array(pd.read_csv('lasso-high.csv', header=None))
data = data[1:][:, 1:]
plt.ylim((-1, 20))
plt.ylabel('Function Value')
plt.plot(range(data.shape[0]), data[:, -1].astype(np.float32), c ='r')
plt.show()

# %% [markdown]
# ### Optimizing custom fuctions

# %% [markdown]
# #### 1. f(x) = sum($x{^2}$)

# %%
from baxus import benchmark_runner
s = ['-a', 'baxus', '-f', 'My_Custom_Benchmark', '-m', '100', '-r', '1', '-id', '100', '-td', '1', '--adjust-initial-target-dimension', '--n-init', '10']
benchmark_runner.main(s)
# Out:
# 10/19/2024 05:16:57 PM INFO: benchmark_runner.py: running combination My_Custom_Benchmark_in_dim_124_t_dim1_n_init_10
# 10/19/2024 05:16:57 PM INFO: benchmark_runner.py: *** BAxUS***
# 10/19/2024 05:16:57 PM INFO: baxus.py: ***************************************************************************************
# * Can reach a difference of 4 with init target dim  of 2 after 3 splits. Adjusting... *
# ***************************************************************************************
# 10/19/2024 05:16:57 PM INFO: embeddedturbo.py: eval 0: creating HeSBO embedding for TuRBO instance...
# 10/19/2024 05:16:57 PM INFO: embeddedturbo.py: Running with the following behavior
#
# 	-initial base length: 0.8
# 	-maximum base length: 1.6
# 	-minimum base length: 0.0078125
# 	-success tolerance: 3
# 	-acquisition_functions: THOMPSON_SAMPLING
# 	-observation noise: 0.0
# 	-embedding type: BAXUS
# 	-success decision factor: 0.001
# 	-number of new bins per dimension: 3
# ...

# %%
data = np.array(pd.read_csv('custom.csv', header=None))
data = data[1:][:, 1:]
plt.plot(range(data.shape[0]), data[:, -1].astype(np.float32), c ='r')
plt.show()
